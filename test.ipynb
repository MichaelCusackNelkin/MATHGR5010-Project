# %%
import databento as db
import numpy as np
import pandas as pd
import glob

# %%
sym_1 = "APPL"

# Get all CSV files in the data folder per desired symbol
sym1_files = glob.glob(f'EQUS-OHLCV-1d/*.ohlcv-1d.{sym_1}.dbn.zst')

# Read all files into a list of dataframes
dfs_sym1 = [db.DBNStore.from_file(file).to_df(tz = "US/Eastern") for file in sym1_files]

# Concatenate and sort
sym1 = pd.concat(dfs_sym1, join='inner').sort_index()

# Combine into one dataframe
data = pd.DataFrame({"sym1": sym1['close']})

data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 10
#       7 dfs_sym1 = [db.DBNStore.from_file(file).to_df(tz = "US/Eastern") for file in sym1_files]
#       9 # Concatenate and sort
# ---> 10 sym1 = pd.concat(dfs_sym1, join='inner').sort_index()
#      12 # Combine into one dataframe
#      13 data = pd.DataFrame({"sym1": sym1['close']})
#
# File ~/GitHub/MATHGR5010-Project/.venv/lib/python3.13/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
# ...
