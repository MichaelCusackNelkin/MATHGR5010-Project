# %%
import yfinance as yf
import pandas as pd

# Copied tickers from top 100 most active from Yfinance :(
tickers = [
    "ONDS", "OPEN", "NVDA", "TSLA", "BBAI", "SOFI", "PLUG", "PFE", "QUBT", "DNN",
    "ACHR", "F", "INTC", "RIVN", "BMNR", "AMZN", "MARA", "NIO", "KVUE", "RIG",
    "PLTR", "SNAP", "GOOGL", "HPE", "LNW", "AAL", "RGTI", "GRAB", "WULF", "CIFR",
    "HOOD", "AMD", "XPEV", "NOK", "IREN", "AAPL", "NU", "GOOG", "BBD", "WBD",
    "BTG", "BTE", "T", "QBTS", "SOUN", "HIMS", "SMCI", "MU", "MTSR", "OWL",
    "CLSK", "B", "BAC", "CRWV", "ABEV", "VALE", "RXRX", "EOSE", "NBIS", "APLD",
    "RKT", "SMR", "JOBY", "CRCL", "NFLX", "CMCSA", "HBAN", "IONQ", "QS", "CLF",
    "COMP", "CSCO", "BULL", "RIOT", "GGB", "CMG", "YMM", "PCG", "VZ", "KEY",
    "AGNC", "HPQ", "PYPL", "MSTR", "CZR", "RKLB", "AMCR", "NGD", "BABA", "LCID",
    "PR", "AUR", "LYFT", "PATH", "DELL", "COIN", "JD", "META", "STLA"
]

rows = []
for t in tickers:
    info = yf.Ticker(t).info
    vol = info.get("regularMarketVolume", None)
    rows.append({"Ticker": t, "Volume": vol})

df = pd.DataFrame(rows)
df_sorted = df.sort_values("Volume", ascending=False)
top50 = df_sorted.head(50)
top50_list = top50["Ticker"].tolist()

print(top50)
# Out:
#    Ticker     Volume
# 2    NVDA  170076362
# 1    OPEN  154718445
# 0    ONDS  153283751
# 3    TSLA   99480658
# 4    BBAI   82581121
# 5    SOFI   75270332
# 7     PFE   72791845
# 6    PLUG   72607607
# 12   INTC   71277888
# 8    QUBT   70941937
# 11      F   66382984
# 9     DNN   65780695
# 10   ACHR   64805744
# 15   AMZN   59392148
# 13   RIVN   57839022
# 14   BMNR   54256150
# 16   MARA   53071118
# 18   KVUE   52600300
# 22  GOOGL   52190848
# 17    NIO   52014277
# 20   PLTR   49762280
# 19    RIG   49349641
# 21   SNAP   48536840
# 23    HPE   43277960
# 35   AAPL   42862157
# 25    AAL   42560978
# 26   RGTI   42077379
# 27   GRAB   41632325
# 28   WULF   41252925
# 30   HOOD   39690274
# 24    LNW   38854866
# 29   CIFR   37938030
# 31    AMD   37631551
# 39    WBD   36650340
# 40    BTG   34451730
# 32   XPEV   34151076
# 37   GOOG   34090105
# 36     NU   33579571
# 34   IREN   33201032
# 33    NOK   32437919
# 46   SMCI   32253343
# 38    BBD   31120862
# 47     MU   30096809
# 41    BTE   29105554
# 42      T   29059566
# 44   SOUN   29038869
# 55   VALE   28101687
# 45   HIMS   28084051
# 50   CLSK   28020611
# 43   QBTS   27944775

# %%
hist = yf.download(top50_list, start="2020-01-01", end="2025-01-01")
# Out:
# C:\Users\derek\AppData\Local\Temp\ipykernel_22340\1229363507.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   hist = yf.download(top50_list, start="2020-01-01", end="2025-01-01")
# [*********************100%***********************]  49 of 50 completed
#
# 2 Failed downloads:
# ['BMNR']: YFPricesMissingError('possibly delisted; no price data found  (1d 2020-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1577854800, endDate = 1735707600")')
# ['HPE']: Timeout('Failed to perform, curl: (28) Operation timed out after 10014 milliseconds with 0 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# [*********************100%***********************]  49 of 50 completed
